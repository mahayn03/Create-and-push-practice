# %%
cats = ["Twix","York"]
print(cats)

# %% [markdown]
# Hello! My name is Megan, I'm 23 and diving into coding excited to learn it all!! I got into computers and what not when playing professional overatch and here I am.
